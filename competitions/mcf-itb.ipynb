# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/laurentiusfarel/mcf-itb-data/Data_Klaim.csv
# /kaggle/input/datasets/laurentiusfarel/mcf-itb-data/sample_submission.csv
# /kaggle/input/datasets/laurentiusfarel/mcf-itb-data/Data_Polis.csv
