# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/salary-prediction-model/submission_sample.csv
# /kaggle/input/salary-prediction-model/train.csv
# /kaggle/input/salary-prediction-model/test.csv

# %%
# !pip install ydata-profiling

# %%
train_df = pd.read_csv('/kaggle/input/salary-prediction-model/train.csv')
test_df = pd.read_csv('/kaggle/input/salary-prediction-model/test.csv')
print("penetapan data berhasil")
# Out:
# penetapan berhasil

# %%
# IMPORT-IMPORT PENTING
import matplotlib.pyplot as plt
import seaborn as sns

print("import berhasil")

# Gaya visualisasi
sns.set_style('whitegrid')
# Out:
# import berhasil

# %% [markdown]
# # EDA TRAIN

# %%
# Muat dataset
file_path = '/kaggle/input/salary-prediction-model/train.csv'
df = pd.read_csv(file_path)

# Tampilkan informasi ringkas tentang dataframe
print("\nInfo DataFrame:")
df.info()

# Tampilkan statistik deskriptif
print("\nStatistik Deskriptif:")
print(df.describe())
# Out:
# Info DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1160 entries, 0 to 1159
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        1160 non-null   object
#  1   Current Position          1019 non-null   object
#  2   Targeted Position         202 non-null    object
#  3   Total Working Experience  1160 non-null   int64
#  4   Candidate Level           1160 non-null   object
#  5   Domisili                  1061 non-null   object
#  6   Education 1               1142 non-null   object
#  7   Education 2               531 non-null    object
#  8   Education 3               129 non-null    object
#  9   Expected Benefit Botom    1160 non-null   int64
#  10  Expected Benefit Up       1160 non-null   int64
#  11  Notice Period             57 non-null     object
#  12  Tech Stack                1155 non-null   object
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Muat data Anda
file_path = '/kaggle/input/salary-prediction-model/train.csv'
df = pd.read_csv(file_path)

# Buat laporan profil
profile = ProfileReport(df, title="Laporan Profiling Gaji (Train Data)")

# GANTI .to_widgets() DENGAN .to_file()
profile.to_file("laporan_gaji.html")

print("Laporan berhasil dibuat dan disimpan sebagai 'laporan_gaji.html'")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Laporan berhasil dibuat dan disimpan sebagai 'laporan_gaji.html'

# %%
import pandas as pd

# Pastikan Anda sudah memuat dataframe 'df' sebelumnya
# file_path = '/kaggle/input/salary-prediction-model/train.csv'
# df = pd.read_csv(file_path)

# Mengatur agar pandas menampilkan lebih banyak baris
pd.set_option('display.max_rows', 200)

print("--- 🎓 Isi Kolom Education 1 ---")
print(df['Education 1'].value_counts(dropna=False))
print("\n" + "="*50 + "\n")

print("--- 🎓 Isi Kolom Education 2 ---")
print(df['Education 2'].value_counts(dropna=False))
print("\n" + "="*50 + "\n")

print("--- 🎓 Isi Kolom Education 3 ---")
print(df['Education 3'].value_counts(dropna=False))
